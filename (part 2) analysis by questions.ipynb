# %%
import numpy as df

# %%
import pandas as pd

# %%
df = pd.read_csv('hotel_booking.csv')

# %%
#for replacing all the null values with zero.(if we exhange country with zero it wont affect the data)
df.fillna(0)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
#the number of customer for every deposit type
df['deposit_type'].value_counts()
# Out:
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %%
#the number of customer for every reserved_room_type
df['reserved_room_type'].value_counts()
# Out:
# A    85994
# D    19201
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: reserved_room_type, dtype: int64

# %%
##the number of customer for every assigned_room_type
df['assigned_room_type'].value_counts()
# Out:
# A    74053
# D    25322
# E     7806
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: assigned_room_type, dtype: int64

# %%
#the number of customer that didn't cancel the booking
len(df[df['is_canceled'] == 1].index)
# Out:
# 44224

# %%
# the number of customer that repeted the booking 
len(df[df['is_repeated_guest'] == 1].index)
# Out:
# 3810

# %%
# the number of customer that had a pervios cancel
len(df[df['previous_cancellations'] == 1].index)
# Out:
# 6051

# %%
 len(df[df['previous_bookings_not_canceled'] == 1].index)
# Out:
# 1542

# %%
#the number of cansel booking for every year
df.groupby('arrival_date_year').count()['is_canceled']
# Out:
# arrival_date_year
# 2015    21996
# 2016    56707
# 2017    40687
# Name: is_canceled, dtype: int64

# %%
#the number of customer that repeted the booking
df.groupby('arrival_date_year').count()['is_repeated_guest']
# Out:
# arrival_date_year
# 2015    21996
# 2016    56707
# 2017    40687
# Name: is_repeated_guest, dtype: int64

# %%
#the number of Transient customer
len(df[df['customer_type'] == 'Transient'].index)
# Out:
# 89613

# %%
# the higest customer type
df[df['customer_type'] == df['customer_type'].max()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 47      Resort Hotel            0        113               2015
# 50      Resort Hotel            0        113               2015
# 127     Resort Hotel            0        100               2015
# 129     Resort Hotel            0        100               2015
# 130     Resort Hotel            0        100               2015
# ...              ...          ...        ...                ...
# 119347    City Hotel            0         63               2017
# 119348    City Hotel            0         63               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 47                   July                        27
# 50                   July                        27
# ...

# %%
#when i want found all the customer type of Transient-Party
df[df['customer_type'] == 'Transient-Party']
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 47      Resort Hotel            0        113               2015
# 50      Resort Hotel            0        113               2015
# 127     Resort Hotel            0        100               2015
# 129     Resort Hotel            0        100               2015
# 130     Resort Hotel            0        100               2015
# ...              ...          ...        ...                ...
# 119347    City Hotel            0         63               2017
# 119348    City Hotel            0         63               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 47                   July                        27
# 50                   July                        27
# ...

# %%
#standard deviation for all lead time
df['lead_time'].std()
# Out:
# 106.86309704798579

# %%
#the average for all lead time
df['lead_time'].mean()
# Out:
# 104.01141636652986

# %%
#the number of reserved room type from type A
len(df[df['reserved_room_type'] == 'A'].index)
# Out:
# 85994

# %%
#the number of direct type from the distribuion_channel
len(df[df['distribution_channel'] == 'Direct'].index)
# Out:
# 14645

# %%
#the number of the customer that take BB mael
len(df[df['meal'] == 'BB'].index)
# Out:
# 92310

# %%
#the number of customer that comes from GRB
len(df[df['country'] == 'GBR'].index)
# Out:
# 12129

# %%
# the numner of the customer type as a group type and their total of special requests tless than 2
df[(df['customer_type']=='Group') & (df['total_of_special_requests']<2)].count()
# Out:
# hotel                             491
# is_canceled                       491
# lead_time                         491
# arrival_date_year                 491
# arrival_date_month                491
# arrival_date_week_number          491
# arrival_date_day_of_month         491
# stays_in_weekend_nights           491
# stays_in_week_nights              491
# adults                            491
# children                          491
# babies                            491
# meal                              491
# country                           485
# market_segment                    491
# distribution_channel              491
# is_repeated_guest                 491
# previous_cancellations            491
# previous_bookings_not_canceled    491
# reserved_room_type                491
# assigned_room_type                491
# booking_changes                   491
# deposit_type                      491
# agent                             399
# company                            48
# ...

# %%
#the number of country as PRT when booking changes>2
df[(df['country']=='PRT') & (df['booking_changes']>2)].count()
# Out:
# hotel                             430
# is_canceled                       430
# lead_time                         430
# arrival_date_year                 430
# arrival_date_month                430
# arrival_date_week_number          430
# arrival_date_day_of_month         430
# stays_in_weekend_nights           430
# stays_in_week_nights              430
# adults                            430
# children                          430
# babies                            430
# meal                              430
# country                           430
# market_segment                    430
# distribution_channel              430
# is_repeated_guest                 430
# previous_cancellations            430
# previous_bookings_not_canceled    430
# reserved_room_type                430
# assigned_room_type                430
# booking_changes                   430
# deposit_type                      430
# agent                             271
# company                            72
# ...

# %%
# the mean for customers types
df.groupby('customer_type').mean()
# Out:
#                  is_canceled   lead_time  arrival_date_year  \
# customer_type
# Contract            0.309617  142.969823        2015.510304
# Group               0.102253   55.057192        2016.045061
# Transient           0.407463   93.295515        2016.249517
# Transient-Party     0.254299  137.037056        2015.932375
#
#                  arrival_date_week_number  arrival_date_day_of_month  \
# customer_type
# Contract                        33.702159                  15.236261
# Group                           29.433276                  15.603120
# Transient                       26.541350                  15.795164
# Transient-Party                 28.277623                  15.904872
#
#                  stays_in_weekend_nights  stays_in_week_nights    adults  \
# customer_type
# Contract                        1.469578              3.851079  1.919529
# Group                           0.824957              2.057192  2.346620
# ...

# %%
 #select the data of Online TA(type of market segment)
df_market_segment = df[df.market_segment == 'Online TA']
df_market_segment
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 8       Resort Hotel            1         85               2015
# 10      Resort Hotel            1         23               2015
# 11      Resort Hotel            0         35               2015
# ...              ...          ...        ...                ...
# 119382    City Hotel            0        135               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 4                    July                        27
# 5                    July                        27
# ...

# %%
#the number of customer that take sc meal
df[df['meal'] == 'SC'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10650 entries, 1655 to 119380
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           10650 non-null  object
#  1   is_canceled                     10650 non-null  int64
#  2   lead_time                       10650 non-null  int64
#  3   arrival_date_year               10650 non-null  int64
#  4   arrival_date_month              10650 non-null  object
#  5   arrival_date_week_number        10650 non-null  int64
#  6   arrival_date_day_of_month       10650 non-null  int64
#  7   stays_in_weekend_nights         10650 non-null  int64
#  8   stays_in_week_nights            10650 non-null  int64
#  9   adults                          10650 non-null  int64
#  10  children                        10650 non-null  float64
#  11  babies                          10650 non-null  int64
# ...

# %%
 #the number of customer that take sc meal
df[df['name'] == 'Cesar Moreno']
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119382  City Hotel            0        135               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119382             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119382                         30                        2
#
#         stays_in_week_nights  adults  ...  customer_type    adr  \
# 119382                     4       3  ...      Transient  209.0
#
#        required_car_parking_spaces total_of_special_requests  \
# 119382                           0                         0
#
#        reservation_status reservation_status_date          name  \
# 119382          Check-Out              2017-09-05  Cesar Moreno
#
#                         email  phone-number       credit_card
# 119382  Cesar_M50@comcast.net  666-379-7260  ************7835
#
# [1 rows x 36 columns]

# %%
#the maxmum value for total of special requestes
df['total_of_special_requests'].max()
# Out:
# 5

# %%
#getting the name of person throw his phone number
df[df["phone-number"] == 666-379-7260]["name"]
# Out:
# Series([], Name: name, dtype: object)

# %%
df[df['company'] == 'Ariana Michae']['phone-number']
# Out:
# Series([], Name: phone-number, dtype: object)
