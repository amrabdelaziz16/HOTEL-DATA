# %%
import numpy as df

# %%
import pandas as pd

# %%
df = pd.read_csv('hotel_booking.csv')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# knowing all the information about the data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# A small describing(summry) for the data.
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#for knowing all the names of the table
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
# the shape of the matrix( the number of rows and columns)
df.shape
# Out:
# (119390, 36)

# %%
# check for null value in te table
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
#for Finding all the null values in the data
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#for replacing all the null values with zero.(if we exhange country with zero it wont affect the data)
df.fillna(0)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#the first 6 rows in th etable
df.head(6)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# 5                        27                          1
#
# ...

# %%
#the number of the hotel or the type of the hotel.
df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
#the number of customer for each hotel for knowing which of them is better or 
df['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
# the average of lead time for all hotels
df['lead_time'].mean()
# Out:
# 104.01141636652986

# %%
df['lead_time'].max()
# Out:
# 737

# %%
df['lead_time'].min()
# Out:
# 0

# %%
# the number of customer for each lead time
df['lead_time'].value_counts()
# Out:
# 0      6345
# 1      3460
# 2      2069
# 3      1816
# 4      1715
#        ...
# 400       1
# 370       1
# 532       1
# 371       1
# 463       1
# Name: lead_time, Length: 479, dtype: int64

# %%
df['is_canceled'].count()
# Out:
# 119390

# %%
#the amount of customer that canceled the booking 
df['is_canceled'].value_counts()
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
df['is_repeated_guest'].count()
# Out:
# 119390

# %%
##the amount of customer that repeated the booking 
df['is_repeated_guest'].value_counts()
# Out:
# 0    115580
# 1      3810
# Name: is_repeated_guest, dtype: int64

# %%
df['previous_cancellations'].count()
# Out:
# 119390

# %%
#the amount of customer that canceled the booking previous
df['previous_cancellations'].value_counts()
# Out:
# 0     112906
# 1       6051
# 2        116
# 3         65
# 24        48
# 11        35
# 4         31
# 26        26
# 25        25
# 6         22
# 19        19
# 5         19
# 14        14
# 13        12
# 21         1
# Name: previous_cancellations, dtype: int64

# %%
df['previous_bookings_not_canceled'].count()
# Out:
# 119390

# %%
#the amount of customer (previous_bookings_not_canceled)
df['previous_bookings_not_canceled'].value_counts()
# Out:
# 0     115770
# 1       1542
# 2        580
# 3        333
# 4        229
#        ...
# 47         1
# 49         1
# 50         1
# 51         1
# 72         1
# Name: previous_bookings_not_canceled, Length: 73, dtype: int64

# %%
#the number of customers that arrived for each month
df['arrival_date_month'].value_counts()
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %%
#the month that has gratest number of customer that aarived in it
df['arrival_date_month'].unique().max()
# Out:
# 'September'

# %%
#the arrangmnt of the week that has gratest number of customer that aarived in it
df['arrival_date_week_number'].unique().max()
# Out:
# 53

# %%
#the arrangmnt of the day that has gratest number of customer that aarived in it
df['arrival_date_day_of_month'].unique().max()
# Out:
# 31

# %%
#the most commen date that the customer arrived in it
df['reservation_status_date'].unique().max()
# Out:
# '2017-09-14'

# %%
#the number of sting in weekend nights
df['stays_in_weekend_nights'].unique()
# Out:
# array([ 0,  1,  2,  4,  3,  6, 13,  8,  5,  7, 12,  9, 16, 18, 19, 10, 14],
#       dtype=int64)

# %%
#the number of sting in week nights
df['stays_in_week_nights'].unique()
# Out:
# array([ 0,  1,  2,  3,  4,  5, 10, 11,  8,  6,  7, 15,  9, 12, 33, 20, 14,
#        16, 21, 13, 30, 19, 24, 40, 22, 42, 50, 25, 17, 32, 26, 18, 34, 35,
#        41], dtype=int64)

# %%
# the number of customer for every number of the nights
df['stays_in_week_nights'].value_counts()
# Out:
# 2     33684
# 1     30310
# 3     22258
# 5     11077
# 4      9563
# 0      7645
# 6      1499
# 10     1036
# 7      1029
# 8       656
# 9       231
# 15       85
# 11       56
# 19       44
# 12       42
# 20       41
# 14       35
# 13       27
# 16       16
# 21       15
# 22        7
# 25        6
# 18        6
# 30        5
# 17        4
# 24        3
# 40        2
# 33        1
# 42        1
# 50        1
# 32        1
# 26        1
# 34        1
# 35        1
# 41        1
# Name: stays_in_week_nights, dtype: int64

# %%
# the number of customer for every number of the nights
df['stays_in_weekend_nights'].value_counts()
# Out:
# 0     51998
# 2     33308
# 1     30626
# 4      1855
# 3      1259
# 6       153
# 5        79
# 8        60
# 7        19
# 9        11
# 10        7
# 12        5
# 13        3
# 16        3
# 14        2
# 18        1
# 19        1
# Name: stays_in_weekend_nights, dtype: int64

# %%
#the number of adults
df['adults'].sum()
# Out:
# 221636

# %%
#the number of children
df['children'].sum()
# Out:
# 12403.0

# %%
#the number of babies
df['babies'].sum()
# Out:
# 949

# %%
# the number of customers for to every meal
df['meal'].value_counts()
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: meal, dtype: int64

# %%
#the number of customer for each country where they come
df['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
#customer type
df['customer_type'].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
#the number for each customer type
df['customer_type'].value_counts()
# Out:
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: customer_type, dtype: int64

# %%
#the number of customers for to the number of total of special requests
df['total_of_special_requests'].value_counts()
# Out:
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: total_of_special_requests, dtype: int64

# %%
##the number of customers for to the number of required_car_parking_spaces
df['required_car_parking_spaces'].value_counts()
# Out:
# 0    111974
# 1      7383
# 2        28
# 3         3
# 8         2
# Name: required_car_parking_spaces, dtype: int64

# %%
#number of each reservation status
df['reservation_status'].value_counts()
# Out:
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: reservation_status, dtype: int64
